# %%
import pandas as pd

# %%
df = pd.read_csv('songs.csv')

# %%
df
# Out:
#                                                 TRACK  \
# 0                                           Satellite
# 1                           Power Trip (feat. Miguel)
# 2                           Power Trip (feat. Miguel)
# 3                           Power Trip (feat. Miguel)
# 4                           Power Trip (feat. Miguel)
# 5                           Power Trip (feat. Miguel)
# 6                           Power Trip (feat. Miguel)
# 7                           Power Trip (feat. Miguel)
# 8                           Power Trip (feat. Miguel)
# 9   Dreams, Fairytales, Fantasies (feat. Brent Fai...
# 10  Dreams, Fairytales, Fantasies (feat. Brent Fai...
# 11  Dreams, Fairytales, Fantasies (feat. Brent Fai...
# 12  Dreams, Fairytales, Fantasies (feat. Brent Fai...
# 13  Dreams, Fairytales, Fantasies (feat. Brent Fai...
# 14                                          The Motto
# 15                                          The Motto
# ...
